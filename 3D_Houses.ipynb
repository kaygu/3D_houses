# %%
# %matplotlib notebook

# %run main.py
# Out:
# Please enter a valid address to plot... or just press enter to view Nollekensstraat 15, 2910, Essen
# Street name: Groenplaats
# Number: 21
# PostalCode: 2000
# Commune: Antwerpen
# Do you desire the detailed plot of the whole process? [Y] or [N]: n
# Opening tiles DSM and DTM number: 7713
# <img src="data:image/png;base64,..." width="639.9999861283738">
# Area: 6999.70 m2
# Floors count (aprox): 35
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="299.99999349767523">
